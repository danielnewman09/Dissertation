# %%
from DBQuerier import DBQuerier as Querier
import numpy as np
import ast
import pandas as pd
from crawlab_toolbox import plotting
from crawlab_toolbox.plotting import timedelta_helper
import datetime

# %%
dateTime_full = np.load('data/full_dateTime.npy',allow_pickle=True)
rms_full = np.load('data/full_rms.npy',allow_pickle=True)


dateTime_individual = np.load('data/dateTime_individual.npy',allow_pickle=True)
rms_individual = np.load('data/rms_individual.npy',allow_pickle=True)
kurtosis_individual = np.load('data/kurtosis_individual.npy',allow_pickle=True)
mean_individual = np.load('data/mean_individual.npy',allow_pickle=True)
skewness_individual = np.load('data/skewness_individual.npy',allow_pickle=True)
variance_individual = np.load('data/variance_individual.npy',allow_pickle=True)

# %%
plotting.generate_plot(dateTime_full,rms_full,
                         ['Bearing 1','Bearing 2','Bearing 3','Bearing 4'],'Time (Days)','RMS (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='Figures/IMS2_Timeseries',
                         filename='RMS_All_Bearings',
                         legend_loc='upper left',
                         file_type='png')

# %%
plotting.generate_plot(dateTime_individual,rms_individual,
                         [''],'Time (Days)','RMS (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='figures',
                         filename='RMS_IMS',
                         file_type='png')

plotting.generate_plot(dateTime_individual,kurtosis_individual,
                         [''],'Time (Days)','Kurtosis (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='figures',
                         filename='Kurtosis_IMS',
                         file_type='png')

plotting.generate_plot(dateTime_individual,mean_individual,
                         [''],'Time (Days)','Mean (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='figures',
                         filename='Mean_IMS',
                         file_type='png')

plotting.generate_plot(dateTime_individual,skewness_individual,
                         [''],'Time (Days)','Skewness (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='figures',
                         filename='Skewness_IMS',
                         file_type='png')

plotting.generate_plot(dateTime_individual,variance_individual,
                         [''],'Time (Days)','Variance (Volts)',showplot=True,
                         template='wide',
                         save_plot=True,
                         transparent=True,
                         folder='figures',
                         filename='Variance_IMS',
                         file_type='png')
